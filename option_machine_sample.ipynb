# %%
import pandas as pd

# %%
data = pd.read_csv('option_data/sample.csv')

# %%
data
# Out:
#      Symbol         Date       Expiry Option Type  Strike Price    Open  \
# 0     NIFTY  02-Aug-2021  30-Sep-2021          CE         17000   15.30
# 1     NIFTY  02-Aug-2021  30-Sep-2021          CE         17050    0.00
# 2     NIFTY  02-Aug-2021  30-Sep-2021          CE         17100   12.45
# 3     NIFTY  02-Aug-2021  30-Sep-2021          CE         17150    0.00
# 4     NIFTY  02-Aug-2021  30-Sep-2021          CE         17200    0.00
# ...     ...          ...          ...         ...           ...     ...
# 1785  NIFTY  31-Aug-2021  30-Sep-2021          CE         16750  332.40
# 1786  NIFTY  31-Aug-2021  30-Sep-2021          CE         16800  296.00
# 1787  NIFTY  31-Aug-2021  30-Sep-2021          CE         16850  265.05
# 1788  NIFTY  31-Aug-2021  30-Sep-2021          CE         16900  246.80
# 1789  NIFTY  31-Aug-2021  30-Sep-2021          CE         16950  220.00
#
#         High     Low   Close     LTP  Settle Price  No. of contracts  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1790 entries, 0 to 1789
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Symbol                    1790 non-null   object
#  1   Date                      1790 non-null   object
#  2   Expiry                    1790 non-null   object
#  3   Option Type               1790 non-null   object
#  4   Strike Price              1790 non-null   int64
#  5   Open                      1790 non-null   float64
#  6   High                      1790 non-null   float64
#  7   Low                       1790 non-null   float64
#  8   Close                     1790 non-null   float64
#  9   LTP                       1790 non-null   float64
#  10  Settle Price              1790 non-null   float64
#  11  No. of contracts          1790 non-null   int64
#  12  Turnover in Lacs          1790 non-null   float64
# ...
